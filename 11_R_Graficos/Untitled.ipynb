# %% [markdown]
# # Estadística R

# %%
# variable aleatoria sample de sexos
#replace True : imagina un sombrero con dos 
# etiquetas hombre o mujer y cuando sacas una de ellas la vuelves a meter

n = 5000
sexos = sample(c('hombre','mujer'),n,replace=TRUE)

# %%
table(sexos)
# Out:
# sexos
# hombre  mujer
#   2472   2528

# %%
# variable aleatoria edades

edades = sample(30:70,n,replace=TRUE)

# %%
edades
# Out:
#    [1] 70 60 63 46 69 38 35 39 43 38 56 54 48 39 65 31 58 30 65 42 54 49 39 55
#   [25] 53 61 67 56 56 67 63 60 38 32 50 46 32 61 46 67 64 54 33 57 36 54 56 57
#   [49] 41 54 43 61 39 44 50 48 66 60 65 58 45 60 48 42 49 38 60 59 58 47 65 32
#   [73] 43 67 55 49 44 49 33 40 32 66 33 57 44 33 41 52 55 37 48 57 56 44 46 41
#   [97] 43 48 62 47 54 50 51 56 67 36 56 51 53 43 68 43 58 34 61 61 31 49 55 66
#  [121] 42 49 48 58 61 43 51 42 53 54 64 58 70 36 58 31 66 70 42 36 30 48 47 30
#  [145] 61 48 61 34 55 30 44 34 63 58 47 38 37 53 52 60 45 63 37 61 44 57 70 49
#  [169] 46 63 35 69 58 56 56 42 61 44 61 66 70 32 31 31 45 69 54 47 58 43 56 55
#  [193] 51 49 30 33 52 39 32 62 52 61 60 34 36 39 42 57 64 65 34 52 60 39 61 55
#  [217] 45 60 65 61 56 52 63 48 32 68 67 53 60 35 47 46 60 59 52 42 63 66 48 70
#  [241] 35 69 40 66 50 42 60 52 34 33 59 48 68 69 37 44 55 60 56 60 55 57 56 30
#  [265] 37 69 68 54 30 70 55 65 51 64 37 49 37 70 31 55 33 55 61 40 31 52 35 61
# ...

# %%
summary(edades)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#      30      40      50      50      60      70

# %%
hola = 3

# %%
hola
# Out:
# [1] 3
